# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import os
plt.style.use('ggplot')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('C:/Users/mir96/문서/Python/임원 데이터.csv', encoding = 'utf-8')

# %%
df
# Out:
#        Date  NHO-N
# 0   2010년_상    1.7
# 1   2010년_하    1.4
# 2   2011년_상    1.8
# 3   2011년_하    0.8
# 4   2012년_상    1.0
# 5   2012년_하    0.2
# 6   2013년_상    1.0
# 7   2013년_하    0.4
# 8   2014년_상    0.5
# 9   2014년_하    1.4
# 10  2015년_상    0.9
# 11  2015년_하    2.8
# 12  2016년_상    0.9
# 13  2016년_하    0.9
# 14  2017년_상    0.9
# 15  2017년_하    0.7
# 16  2018년_상    2.0
# 17  2018년_하    0.8
# 18  2019년_상    0.7
# 19  2019년_하    0.8
# 20  2020년_상    0.4
# 21  2020년_하    1.1
# 22  2021년_상    1.5
# 23  2021년_하    1.5
# 24  2022년_상    1.0
# 25  2022년_하    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    26 non-null     object
#  1   NHO-N   25 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 544.0+ bytes

# %%
df1 = df.fillna(df.mean()) #결측치 평균값으로 대체
# Out:
# C:\Users\mir96\AppData\Local\Temp\ipykernel_10180\4091565488.py:1: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
df1
# Out:
#        Date  NHO-N
# 0   2010년_상  1.700
# 1   2010년_하  1.400
# 2   2011년_상  1.800
# 3   2011년_하  0.800
# 4   2012년_상  1.000
# 5   2012년_하  0.200
# 6   2013년_상  1.000
# 7   2013년_하  0.400
# 8   2014년_상  0.500
# 9   2014년_하  1.400
# 10  2015년_상  0.900
# 11  2015년_하  2.800
# 12  2016년_상  0.900
# 13  2016년_하  0.900
# 14  2017년_상  0.900
# 15  2017년_하  0.700
# 16  2018년_상  2.000
# 17  2018년_하  0.800
# 18  2019년_상  0.700
# 19  2019년_하  0.800
# 20  2020년_상  0.400
# 21  2020년_하  1.100
# 22  2021년_상  1.500
# 23  2021년_하  1.500
# 24  2022년_상  1.000
# 25  2022년_하  1.084

# %%
plt.figure(figsize=(22,8))
plt.plot(df1['Date'], df1['NHO-N'])
plt.title("NHO3-N")
plt.xlabel("Date")
plt.ylabel("NHO-N Value")
plt.show()
# Out:
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.

# %%
#TimeSeries 형태로 변경
timeSeries = df1.loc[:, ["Date", "NHO-N"]]
timeSeries.index = timeSeries.Date
ts = timeSeries.drop("Date",axis = 1)
ts
# Out:
#          NHO-N
# Date
# 2010년_상  1.700
# 2010년_하  1.400
# 2011년_상  1.800
# 2011년_하  0.800
# 2012년_상  1.000
# 2012년_하  0.200
# 2013년_상  1.000
# 2013년_하  0.400
# 2014년_상  0.500
# 2014년_하  1.400
# 2015년_상  0.900
# 2015년_하  2.800
# 2016년_상  0.900
# 2016년_하  0.900
# 2017년_상  0.900
# 2017년_하  0.700
# 2018년_상  2.000
# 2018년_하  0.800
# 2019년_상  0.700
# 2019년_하  0.800
# 2020년_상  0.400
# 2020년_하  1.100
# 2021년_상  1.500
# 2021년_하  1.500
# 2022년_상  1.000
# 2022년_하  1.084

# %%
#시계열 분해법
from statsmodels.tsa.seasonal import seasonal_decompose
# 반기 주기라 period = 6으로 설정
result = seasonal_decompose(ts['NHO-N'], model='additive', period= 6)
fig = plt.figure()
fig = result.plot()
fig.set_size_inches(20,15)
# Out:
# C:\Users\mir96\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py:338: UserWarning:
#
# Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#
# C:\Users\mir96\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py:338: UserWarning:
#
# Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#
# C:\Users\mir96\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py:338: UserWarning:
#
# Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.

# %%
#ACF 그래프
import statsmodels.api as sm

fig = plt.figure(figsize = (20, 8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ts, lags=20, ax=ax1)

# %%
#가설 검증
#H0: 정당성 만족 X , #H1 : 장당성 만족
from statsmodels.tsa.stattools import adfuller
result = adfuller(ts)
print ('ADF Statistic : %f' % result[0])
print ('p-value: %f' % result[1])
print ('Critical Value: ')
for key, value in result[4]. items():
    print('\t%s : %.3f' % (key, value))
# Out:
# ADF Statistic : -3.500987
# p-value: 0.007962
# Critical Value:
# 	1% : -3.924
# 	5% : -3.068
# 	10% : -2.674

# %%
# ACF와 PACF그래프
fig = plt.figure(figsize=(20,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ts[1:], lags = 20, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(ts[1:], lags=11 , ax=ax2)
# Out:
# C:\Users\mir96\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning:
#
# The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.

# %% [markdown]
# #1차 차분
# ts_diff = ts - ts.shift()
# plt.figure(figsize=(22,8))
# plt.plot(ts_diff)
# plt.title("diff data")
# plt.xlabel("Date")
# plt.ylabel("diff nho3-n Value")
# plt.show()

# %% [markdown]
# #차분한 값 ACF & PACF
# fig = plt.figure(figsize=(20,8))
# ax1 = fig.add_subplot(211)
# fig = sm.graphics.tsa.plot_acf(ts_diff[1:], lags = 11, ax=ax1)
# ax2 = fig.add_subplot(212)
# fig = sm.graphics.tsa.plot_pacf(ts_diff[1:], lags= 11 , ax=ax2)

# %% [markdown]
# #귀납
# result = adfuller(ts_diff[1:])
# print ('ADF Statistic : %f' % result[0])
# print ('p-value: %f' % result[1])
# print ('Critical Value: ')
# for key, value in result[4]. items():
#     print('\t%s : %.3f' % (key, value))

# %%
#ARIMA 적용 모델 테스트
pip install pmdarima
# Out:
#   Input In [36]
#     pip install pmdarima
#         ^
# SyntaxError: invalid syntax

# %%
from pmdarima.arima import auto_arima
model_arima = auto_arima(ts,
                         trace=True, 
                         error_action='ignore', 
                         start_p=1,
                         start_q=1,
                         max_p=5,
                         max_q=5,
                         suppress_warnings=True,
                         stepwise=False,
                         seasonal=False)

model_arima.fit(ts)
# Out:
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=86.008, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=77.392, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=63.824, Time=0.03 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=63.754, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=58.214, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=60.069, Time=0.02 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=62.052, Time=0.03 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=55.620, Time=0.04 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0]
# Total fit time: 1.503 seconds
# ARIMA(order=(5, 0, 0), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(ts, order= (5,0,0))
model_fit = model.fit()
# Out:
# C:\Users\mir96\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# C:\Users\mir96\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# C:\Users\mir96\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.

# %%
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  NHO-N   No. Observations:                   26
# Model:                 ARIMA(5, 0, 0)   Log Likelihood                 -17.272
# Date:                Tue, 27 Dec 2022   AIC                             48.545
# Time:                        19:28:52   BIC                             57.352
# Sample:                             0   HQIC                            51.081
#                                  - 26
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0569      0.097     10.866      0.000       0.866       1.248
# ar.L1          0.0172      0.371      0.046      0.963      -0.709       0.744
# ar.L2          0.2142      0.214      0.999      0.318      -0.206       0.635
# ar.L3         -0.2836      0.297     -0.954      0.340      -0.866       0.299
# ar.L4         -0.4133      0.241     -1.716      0.086      -0.885       0.059
# ar.L5          0.2004      0.237      0.847      0.397      -0.263       0.664
# sigma2         0.2106      0.074      2.857      0.004       0.066       0.355
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 0.61
# Prob(Q):                              0.76   Prob(JB):                         0.74
# Heteroskedasticity (H):               0.48   Skew:                             0.35
# Prob(H) (two-sided):                  0.29   Kurtosis:                         3.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
from statsmodels.graphics.tsaplots import plot_predict
fig, ax = plt.subplots()
ax = ts.loc['2010년_상':].plot(ax=ax)
fig = plot_predict(model_fit, ax=ax)
plt.show()
# Out:
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.

# %%
model_fit.predict()
# Out:
# Date
# 2010년_상    1.056942
# 2010년_하    1.069608
# 2011년_상    1.133797
# 2011년_하    0.957324
# 2012년_상    0.835742
# 2012년_하    0.777254
# 2013년_상    0.864463
# 2013년_하    1.143618
# 2014년_상    1.248493
# 2014년_하    1.265540
# 2015년_상    0.981678
# 2015년_하    1.545785
# 2016년_상    1.054636
# 2016년_하    1.218760
# 2017년_상    0.659912
# 2017년_하    0.313246
# 2018년_상    1.475798
# 2018년_하    1.074657
# 2019년_상    1.389182
# 2019년_하    0.844392
# 2020년_상    0.587616
# 2020년_하    1.386960
# 2021년_상    1.085866
# 2021년_하    1.294781
# 2022년_상    1.367320
# 2022년_하    0.875801
# Name: predicted_mean, dtype: float64

# %%
fore = model_fit.forecast(6)
fore
# Out:
# C:\Users\mir96\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# 26    0.745070
# 27    0.979165
# 28    1.093429
# 29    1.106760
# 30    1.221997
# 31    1.029769
# Name: predicted_mean, dtype: float64

# %%
fr = pd.Series(fore, index = [26, 27, 28, 29, 30, 31])
fr = fr.to_frame()

# %%
fr
# Out:
#     predicted_mean
# 26        0.745070
# 27        0.979165
# 28        1.093429
# 29        1.106760
# 30        1.221997
# 31        1.029769

# %%
fig, ax = plt.subplots()
ax = ts.loc['2010년_상':].plot(ax=ax)
fig = plot_predict(model_fit, ax=ax)
fig2 = fr.plot(ax=ax)
plt.legend()
plt.show()
# Out:
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#
# C:\Users\mir96\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning:
#
# Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.
